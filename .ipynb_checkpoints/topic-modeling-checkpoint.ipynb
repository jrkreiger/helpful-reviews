# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('./data/Reviews.csv')
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %%
data = df['Text']
data.head()
# Out:
# 0    I have bought several of the Vitality canned d...
# 1    Product arrived labeled as Jumbo Salted Peanut...
# 2    This is a confection that has been around a fe...
# 3    If you are looking for the secret ingredient i...
# 4    Great taffy at a great price.  There was a wid...
# Name: Text, dtype: object

# %%
# Set up stopwords to be removed
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
import string

stop_list = stopwords.words('english')
stop_list += list(string.punctuation)
stop_list += ['br', '.<', '..', '...', '``', "''", '--']
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jennykreiger/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Topic modeling for full dataset

# %%
# Author: Olivier Grisel <olivier.grisel@ensta.org>
#         Lars Buitinck
#         Chyi-Kwei Yau <chyikwei.yau@gmail.com>
# License: BSD 3 clause

from time import time

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
from sklearn.datasets import fetch_20newsgroups

n_samples = 2000
n_features = 1000
n_components = 21
n_top_words = 10


def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        message = "Topic #%d: " % topic_idx
        message += " ".join([feature_names[i]
                             for i in topic.argsort()[:-n_top_words - 1:-1]])
        print(message)
    print()


# Load the 20 newsgroups dataset and vectorize it. We use a few heuristics
# to filter out useless terms early on: the posts are stripped of headers,
# footers and quoted replies, and common English words, words occurring in
# only one document or in at least 95% of the documents are removed.

print("Loading dataset...")
t0 = time()
# data, _ = fetch_20newsgroups(shuffle=True, random_state=1,
#                              remove=('headers', 'footers', 'quotes'),
#                              return_X_y=True)
data_samples = data[:n_samples]
print("done in %0.3fs." % (time() - t0))

# Use tf-idf features for NMF.
print("Extracting tf-idf features for NMF...")
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2,
                                   max_features=n_features,
                                   stop_words=stop_list)
t0 = time()
tfidf = tfidf_vectorizer.fit_transform(data_samples)
print("done in %0.3fs." % (time() - t0))

# Use tf (raw term count) features for LDA.
print("Extracting tf features for LDA...")
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2,
                                max_features=n_features,
                                stop_words=stop_list)
t0 = time()
tf = tf_vectorizer.fit_transform(data_samples)
print("done in %0.3fs." % (time() - t0))
print()

# Fit the NMF model
print("Fitting the NMF model (Frobenius norm) with tf-idf features, "
      "n_samples=%d and n_features=%d..."
      % (n_samples, n_features))
t0 = time()
nmf = NMF(n_components=n_components, random_state=1,
          alpha=.1, l1_ratio=.5).fit(tfidf)
print("done in %0.3fs." % (time() - t0))

print("\nTopics in NMF model (Frobenius norm):")
tfidf_feature_names = tfidf_vectorizer.get_feature_names()
print_top_words(nmf, tfidf_feature_names, n_top_words)

# Fit the NMF model
print("Fitting the NMF model (generalized Kullback-Leibler divergence) with "
      "tf-idf features, n_samples=%d and n_features=%d..."
      % (n_samples, n_features))
t0 = time()
nmf = NMF(n_components=n_components, random_state=1,
          beta_loss='kullback-leibler', solver='mu', max_iter=1000, alpha=.1,
          l1_ratio=.5).fit(tfidf)
print("done in %0.3fs." % (time() - t0))

print("\nTopics in NMF model (generalized Kullback-Leibler divergence):")
tfidf_feature_names = tfidf_vectorizer.get_feature_names()
print_top_words(nmf, tfidf_feature_names, n_top_words)

print("Fitting LDA models with tf features, "
      "n_samples=%d and n_features=%d..."
      % (n_samples, n_features))
lda = LatentDirichletAllocation(n_components=n_components, max_iter=5,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=0)
t0 = time()
lda.fit(tf)
print("done in %0.3fs." % (time() - t0))

print("\nTopics in LDA model:")
tf_feature_names = tf_vectorizer.get_feature_names()
print_top_words(lda, tf_feature_names, n_top_words)
# Out:
# Loading dataset...
# done in 0.007s.
# Extracting tf-idf features for NMF...
# done in 0.143s.
# Extracting tf features for LDA...
# done in 0.145s.
#
# Fitting the NMF model (Frobenius norm) with tf-idf features, n_samples=2000 and n_features=1000...
# done in 0.402s.
#
# Topics in NMF model (Frobenius norm):
# Topic #0: time much use make get bag well box even little
# Topic #1: chips kettle potato bag chip brand bags salty spicy regular
# Topic #2: tea teas drink black drinking green loose iced years wonderful
# Topic #3: food dog dogs loves cat cats old harmony farms treats
# Topic #4: like taste really others better feel salty kind even bad
# Topic #5: great taste snack tastes size healthy loves eat looking without
# Topic #6: coffee cup bitter drink instant pods blend cups tastes use
# Topic #7: salt vinegar sea pepper favorite sour bbq onion chips original
# Topic #8: one eat favorite baby little rice try many sweet tried
# Topic #9: product use dirty using quite quality delivery thanks happy juice
# Topic #10: love delicious stuff way get cats also husband perfect flavored
# Topic #11: good really pretty healthy tastes taste tasting tasty try eat
# Topic #12: flavors popchips variety pack calories 100 snack calorie fat bag
# Topic #13: sugar raw use cubes stevia white brown regular sweet agave
# Topic #14: flavor favorite bbq strong really probably far better bit original
# Topic #15: hot sauce bottle spicy salsa sweet soy tasty chicken little
# Topic #16: com amazon www http href gp pack ounce product 24
# Topic #17: best ever tried tasted tasting eaten earth stevia market far
# Topic #18: price amazon find local stores store grocery cereal shipping online
# Topic #19: buy would recommend never thought loved okay highly definitely way
# Topic #20: chocolate dark pocky mint version cups caramel wonderful cookies stick
#
# Fitting the NMF model (generalized Kullback-Leibler divergence) with tf-idf features, n_samples=2000 and n_features=1000...
# done in 3.014s.
#
# Topics in NMF model (generalized Kullback-Leibler divergence):
# Topic #0: get time like know first actually also bad two long
# Topic #1: chips potato bag chip kettle flavor salt bags crunchy salty
# Topic #2: tea drink like black drinking flavor teas green bitter nice
# Topic #3: food dog old eat loves year dogs one ingredients also
# Topic #4: like taste even bit flavor really bad tried anything little
# Topic #5: great flavors love snack favorite popchips salt pepper variety pack
# Topic #6: coffee bags box ordered get great could day order bought
# Topic #7: amazon product order found find store grocery disappointed local item
# Topic #8: best favorite one love time flavor tried many every first
# Topic #9: great product better taste use also make used purchase brands
# Topic #10: love also much use absolutely get delicious sweet product go
# Topic #11: good great price taste really find makes fast healthy delivery
# Topic #12: flavor try product pack really flavors enjoy ordered variety family
# Topic #13: good eat use could make sugar need one found day
# Topic #14: amazon find buy flavor better much store great stores local
# Topic #15: little great bag came tasty fresh perfect hot easy water
# Topic #16: amazon mix com add make easy like gp http makes
# Topic #17: best ever buy like tasted come arrived small chocolate friends
# Topic #18: bag price like calories fat high get per less shipping
# Topic #19: would buy recommend highly bought loved anyone regular baked much
# Topic #20: free taste candy eat get gluten looking chocolate many size
#
# Fitting LDA models with tf features, n_samples=2000 and n_features=1000...
# done in 3.647s.
#
# Topics in LDA model:
# Topic #0: sugar salt free gluten use cookies flour baked ginger syrup
# Topic #1: yum shape rather miss someone often sell stock able back
# Topic #2: sauce hot soy bottle love ramen middle japanese flavor meal
# Topic #3: oats tiny melt cold chewy treat oatmeal recommend shipped summer
# Topic #4: love eat arrived expensive absolutely oats bags right however good
# Topic #5: food dog eat dogs old one treats foods also cats
# Topic #6: tea coffee organic drink green one stevia like bitter teas
# Topic #7: candy licorice pack water cake pod like pods cup donut
# Topic #8: roasted bean yet beans course second outside top slightly first
# Topic #9: back finally six daughter brought strawberry loves allergies milk hit
# Topic #10: product juice weight powder olive meat watchers recommend cacao canned
# Topic #11: chips flavor like good great bag salt taste flavors potato
# Topic #12: keeps combination expensive worse control type enjoy well water gets
# Topic #13: good product one great like amazon love price taste would
# Topic #14: turkey wonderful apples used water carrots addition daily clean teeth
# Topic #15: chocolate taste sugar fruit like great low raw diet energy
# Topic #16: box arrived lollipops received condition order great packaged service quick
# Topic #17: egg formula allergies touch new loves night food gas dog
# Topic #18: garlic market bite jars waste fantastic six first saw bottom
# Topic #19: style stores ok far pocky brands enjoyed exactly tried want
# Topic #20: chips com amazon product http www gp href kettle salsa

# %%
X = tfidf
y = df['HelpfulnessNumerator']

# %%
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

from yellowbrick.cluster import KElbowVisualizer

# Generate synthetic dataset with 8 random clusters
# X, y = make_blobs(n_samples=1000, n_features=12, centers=8, random_state=42)

# Instantiate the clustering model and visualizer
model = KMeans()
visualizer = KElbowVisualizer(model, k=(10, 20))

visualizer.fit(X)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure
# Out:
# /Users/jennykreiger/anaconda3/envs/learn-env/lib/python3.6/site-packages/yellowbrick/utils/kneed.py:140: YellowbrickWarning: No 'knee' or 'elbow point' detected This could be due to bad clustering, no actual clusters being formed etc.
#   warnings.warn(warning_message, YellowbrickWarning)
# /Users/jennykreiger/anaconda3/envs/learn-env/lib/python3.6/site-packages/yellowbrick/cluster/elbow.py:343: YellowbrickWarning: No 'knee' or 'elbow' point detected, pass `locate_elbow=False` to remove the warning
#   warnings.warn(warning_message, YellowbrickWarning)

# %%
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

from yellowbrick.cluster import KElbowVisualizer

# Generate synthetic dataset with 8 random clusters
# X, y = make_blobs(n_samples=1000, n_features=12, centers=8, random_state=42)

# Instantiate the clustering model and visualizer
model = KMeans()
visualizer = KElbowVisualizer(model, k=(15, 25))

visualizer.fit(X)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure

# %%
# What if I try it with only two topics? Will they align with helpful/not?

# Author: Olivier Grisel <olivier.grisel@ensta.org>
#         Lars Buitinck
#         Chyi-Kwei Yau <chyikwei.yau@gmail.com>
# License: BSD 3 clause

from time import time

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
from sklearn.datasets import fetch_20newsgroups

n_samples = 2000
n_features = 1000
n_components = 2
n_top_words = 30


def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        message = "Topic #%d: " % topic_idx
        message += " ".join([feature_names[i]
                             for i in topic.argsort()[:-n_top_words - 1:-1]])
        print(message)
    print()


# Load the 20 newsgroups dataset and vectorize it. We use a few heuristics
# to filter out useless terms early on: the posts are stripped of headers,
# footers and quoted replies, and common English words, words occurring in
# only one document or in at least 95% of the documents are removed.

print("Loading dataset...")
t0 = time()
# data, _ = fetch_20newsgroups(shuffle=True, random_state=1,
#                              remove=('headers', 'footers', 'quotes'),
#                              return_X_y=True)
data_samples = data[:n_samples]
print("done in %0.3fs." % (time() - t0))

# Use tf-idf features for NMF.
print("Extracting tf-idf features for NMF...")
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2,
                                   max_features=n_features,
                                   stop_words=stop_list)
t0 = time()
tfidf = tfidf_vectorizer.fit_transform(data_samples)
print("done in %0.3fs." % (time() - t0))

# Use tf (raw term count) features for LDA.
print("Extracting tf features for LDA...")
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2,
                                max_features=n_features,
                                stop_words=stop_list)
t0 = time()
tf = tf_vectorizer.fit_transform(data_samples)
print("done in %0.3fs." % (time() - t0))
print()

# Fit the NMF model
print("Fitting the NMF model (Frobenius norm) with tf-idf features, "
      "n_samples=%d and n_features=%d..."
      % (n_samples, n_features))
t0 = time()
nmf = NMF(n_components=n_components, random_state=1,
          alpha=.1, l1_ratio=.5).fit(tfidf)
print("done in %0.3fs." % (time() - t0))

print("\nTopics in NMF model (Frobenius norm):")
tfidf_feature_names = tfidf_vectorizer.get_feature_names()
print_top_words(nmf, tfidf_feature_names, n_top_words)

# Fit the NMF model
print("Fitting the NMF model (generalized Kullback-Leibler divergence) with "
      "tf-idf features, n_samples=%d and n_features=%d..."
      % (n_samples, n_features))
t0 = time()
nmf = NMF(n_components=n_components, random_state=1,
          beta_loss='kullback-leibler', solver='mu', max_iter=1000, alpha=.1,
          l1_ratio=.5).fit(tfidf)
print("done in %0.3fs." % (time() - t0))

print("\nTopics in NMF model (generalized Kullback-Leibler divergence):")
tfidf_feature_names = tfidf_vectorizer.get_feature_names()
print_top_words(nmf, tfidf_feature_names, n_top_words)

print("Fitting LDA models with tf features, "
      "n_samples=%d and n_features=%d..."
      % (n_samples, n_features))
lda = LatentDirichletAllocation(n_components=n_components, max_iter=5,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=0)
t0 = time()
lda.fit(tf)
print("done in %0.3fs." % (time() - t0))

print("\nTopics in LDA model:")
tf_feature_names = tf_vectorizer.get_feature_names()
print_top_words(lda, tf_feature_names, n_top_words)
# Out:
# Loading dataset...
# done in 0.002s.
# Extracting tf-idf features for NMF...
# done in 0.157s.
# Extracting tf features for LDA...
# done in 0.146s.
#
# Fitting the NMF model (Frobenius norm) with tf-idf features, n_samples=2000 and n_features=1000...
# done in 0.059s.
#
# Topics in NMF model (Frobenius norm):
# Topic #0: tea good product like one great food taste love coffee amazon price use really get would find flavor buy little time much sugar best better tried eat make also well
# Topic #1: chips salt potato kettle flavor bag vinegar great chip flavors like bags love taste snack salty popchips pepper good calories regular variety sea pack favorite brand crunchy bbq greasy best
#
# Fitting the NMF model (generalized Kullback-Leibler divergence) with tf-idf features, n_samples=2000 and n_features=1000...
# done in 0.360s.
#
# Topics in NMF model (generalized Kullback-Leibler divergence):
# Topic #0: great good like love taste product one buy amazon best flavor get find also really eat better much would food price time little even bought try make use bag tried
# Topic #1: chips salt flavor bag potato chip bags flavors kettle vinegar snack calories salty crunchy bbq delicious popchips pepper pack favorite variety fat 100 crunch low healthy greasy regular cheddar spicy
#
# Fitting LDA models with tf features, n_samples=2000 and n_features=1000...
# done in 4.593s.
#
# Topics in LDA model:
# Topic #0: like product good great one taste tea flavor use amazon would price love time find coffee get much really sugar best make buy tried well little better even box also
# Topic #1: chips food like flavor good bag salt great love flavors potato taste bags kettle one eat really dog also chip vinegar would much buy fat try healthy best get favorite

# %% [markdown]
# # Topic modeling for dataset with duplicates removed

# %%
# Drop duplicate reviews based on identical texts
no_dupes = df.drop_duplicates(subset=['Text'])

# %%
data = no_dupes['Text']

# %%
# What if I try it with only two topics? Will they align with helpful/not?

# Author: Olivier Grisel <olivier.grisel@ensta.org>
#         Lars Buitinck
#         Chyi-Kwei Yau <chyikwei.yau@gmail.com>
# License: BSD 3 clause

from time import time

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
from sklearn.datasets import fetch_20newsgroups

n_samples = 2000
n_features = 1000
n_components = 20
n_top_words = 10


def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        message = "Topic #%d: " % topic_idx
        message += " ".join([feature_names[i]
                             for i in topic.argsort()[:-n_top_words - 1:-1]])
        print(message)
    print()


# Load the 20 newsgroups dataset and vectorize it. We use a few heuristics
# to filter out useless terms early on: the posts are stripped of headers,
# footers and quoted replies, and common English words, words occurring in
# only one document or in at least 95% of the documents are removed.

print("Loading dataset...")
t0 = time()
# data, _ = fetch_20newsgroups(shuffle=True, random_state=1,
#                              remove=('headers', 'footers', 'quotes'),
#                              return_X_y=True)
data_samples = data[:n_samples]
print("done in %0.3fs." % (time() - t0))

# Use tf-idf features for NMF.
print("Extracting tf-idf features for NMF...")
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2,
                                   max_features=n_features,
                                   stop_words=stop_list)
t0 = time()
tfidf = tfidf_vectorizer.fit_transform(data_samples)
print("done in %0.3fs." % (time() - t0))

# Use tf (raw term count) features for LDA.
print("Extracting tf features for LDA...")
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2,
                                max_features=n_features,
                                stop_words=stop_list)
t0 = time()
tf = tf_vectorizer.fit_transform(data_samples)
print("done in %0.3fs." % (time() - t0))
print()

# Fit the NMF model
print("Fitting the NMF model (Frobenius norm) with tf-idf features, "
      "n_samples=%d and n_features=%d..."
      % (n_samples, n_features))
t0 = time()
nmf = NMF(n_components=n_components, random_state=1,
          alpha=.1, l1_ratio=.5).fit(tfidf)
print("done in %0.3fs." % (time() - t0))

print("\nTopics in NMF model (Frobenius norm):")
tfidf_feature_names = tfidf_vectorizer.get_feature_names()
print_top_words(nmf, tfidf_feature_names, n_top_words)

# Fit the NMF model
print("Fitting the NMF model (generalized Kullback-Leibler divergence) with "
      "tf-idf features, n_samples=%d and n_features=%d..."
      % (n_samples, n_features))
t0 = time()
nmf = NMF(n_components=n_components, random_state=1,
          beta_loss='kullback-leibler', solver='mu', max_iter=1000, alpha=.1,
          l1_ratio=.5).fit(tfidf)
print("done in %0.3fs." % (time() - t0))

print("\nTopics in NMF model (generalized Kullback-Leibler divergence):")
tfidf_feature_names = tfidf_vectorizer.get_feature_names()
print_top_words(nmf, tfidf_feature_names, n_top_words)

print("Fitting LDA models with tf features, "
      "n_samples=%d and n_features=%d..."
      % (n_samples, n_features))
lda = LatentDirichletAllocation(n_components=n_components, max_iter=5,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=0)
t0 = time()
lda.fit(tf)
print("done in %0.3fs." % (time() - t0))

print("\nTopics in LDA model:")
tf_feature_names = tf_vectorizer.get_feature_names()
print_top_words(lda, tf_feature_names, n_top_words)
# Out:
# Loading dataset...
# done in 0.000s.
# Extracting tf-idf features for NMF...
# done in 0.149s.
# Extracting tf features for LDA...
# done in 0.142s.
#
# Fitting the NMF model (Frobenius norm) with tf-idf features, n_samples=2000 and n_features=1000...
# done in 0.340s.
#
# Topics in NMF model (Frobenius norm):
# Topic #0: one little time much use bag eat try tried well
# Topic #1: chips kettle potato bag chip bags salty brand regular crunchy
# Topic #2: tea teas drink black drinking green loose iced years morning
# Topic #3: food cat cats old eat baby problems dogs dry foods
# Topic #4: like really better others even kind spicy nothing lot though
# Topic #5: salt vinegar sea pepper favorite sour bbq onion original chips
# Topic #6: coffee cup bitter drink instant blend pods tastes cups use
# Topic #7: price amazon find local stores store grocery cereal shipping found
# Topic #8: love delicious stuff way also husband get sweet pasta flavored
# Topic #9: great snack tastes size loves make healthy looking deal without
# Topic #10: sugar raw use white stevia brown regular agave much sweet
# Topic #11: good really pretty tastes healthy tasty tasting stuff try however
# Topic #12: product http www href gp com use using ounce amazon
# Topic #13: flavors popchips pack variety calories 100 snack bags single 24
# Topic #14: flavor favorite bbq hot sauce strong probably far better really
# Topic #15: mix waffle pancake easy make pancakes add milk waffles cup
# Topic #16: taste energy healthy also feel amazing get salty bad wonderful
# Topic #17: dog treats loves dogs food harmony farms liver small natural
# Topic #18: best ever tried tasted tasting market eaten earth stevia real
# Topic #19: buy would recommend never thought highly loved okay definitely way
#
# Fitting the NMF model (generalized Kullback-Leibler divergence) with tf-idf features, n_samples=2000 and n_features=1000...
# done in 2.947s.
#
# Topics in NMF model (generalized Kullback-Leibler divergence):
# Topic #0: good time much first two enough get long actually one
# Topic #1: chips potato chip kettle salt flavor bag bags crunchy vinegar
# Topic #2: tea drink black flavor drinking like green teas coffee bitter
# Topic #3: food dog dogs old eat loves year one dry ingredients
# Topic #4: like taste flavor even bit better bad really one tried
# Topic #5: great flavors love favorite salt popchips flavor pepper variety snack
# Topic #6: coffee great box bought ordered one order flavors delicious bags
# Topic #7: amazon product order store even price disappointed grocery found bought
# Topic #8: best ever favorite love time one flavor many far every
# Topic #9: great product better taste use looking made used natural sugar
# Topic #10: love much also use delicious sugar absolutely go get way
# Topic #11: good really delivery pretty makes tasty quality always brand find
# Topic #12: flavor product pack like com really variety 24 gp enjoy
# Topic #13: calories free excellent make 100 diet low fat one regular
# Topic #14: amazon find great flavor hard stores buy local found like
# Topic #15: little make easy add mix like perfect use hot water
# Topic #16: taste get like eat amazon know family tried husband almost
# Topic #17: arrived chocolate fresh came loves ordered bought candy gift well
# Topic #18: bag buy like bags best taste anything high way big
# Topic #19: buy would price recommend one highly free eat anyone well
#
# Fitting LDA models with tf features, n_samples=2000 and n_features=1000...
# done in 3.050s.
#
# Topics in LDA model:
# Topic #0: salt vinegar sauce sea pepper sour chips sodium love onion
# Topic #1: gold prices target watch good less salt box purchase price
# Topic #2: coffee ordered great would back open box pod treats received
# Topic #3: cereal filled market jars waste ingredient price half even little
# Topic #4: dirty lollipops arrived expected well seller instant oats birthday oatmeal
# Topic #5: exactly strawberry six daughter filling loves perfect ask pounds would
# Topic #6: oatmeal recipes gum mccann instant syrup water together agave wonderful
# Topic #7: chips potato kettle pack amazon com flavors www http product
# Topic #8: food dogs dog old cats cat baby formula farms foods
# Topic #9: dog ginger spicy food thai noodles loves treats soda ramen
# Topic #10: meat canned dry steaks omaha frozen quality 00 offered turkey
# Topic #11: jars babies earth apples selling around treat colors yummy tiny
# Topic #12: pineapple difference flavoring bad food variety unlike well oatmeal water
# Topic #13: apple fact prepare needed loved alternative nice easy love fresh
# Topic #14: coffee ended friend chance ready sometimes found say tea morning
# Topic #15: mix make add oil easy use water powder fruit milk
# Topic #16: like good chips great taste flavor one love product bag
# Topic #17: extremely less children fit throw fast great top definitely cat
# Topic #18: chocolate licorice candy cake cookies really made caramels frosting like
# Topic #19: popchips weight low carb watchers diet points stevia calorie nustevia

# %%
X = tfidf

# %%
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

from yellowbrick.cluster import KElbowVisualizer

# Generate synthetic dataset with 8 random clusters
# X, y = make_blobs(n_samples=1000, n_features=12, centers=8, random_state=42)

# Instantiate the clustering model and visualizer
model = KMeans()
visualizer = KElbowVisualizer(model, k=(10, 25))

visualizer.fit(X)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure

# %%
# What if I try it with only two topics? Will they align with helpful/not?

# Author: Olivier Grisel <olivier.grisel@ensta.org>
#         Lars Buitinck
#         Chyi-Kwei Yau <chyikwei.yau@gmail.com>
# License: BSD 3 clause

from time import time

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
from sklearn.datasets import fetch_20newsgroups

n_samples = 2000
n_features = 1000
n_components = 21
n_top_words = 10


def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        message = "Topic #%d: " % topic_idx
        message += " ".join([feature_names[i]
                             for i in topic.argsort()[:-n_top_words - 1:-1]])
        print(message)
    print()


# Load the 20 newsgroups dataset and vectorize it. We use a few heuristics
# to filter out useless terms early on: the posts are stripped of headers,
# footers and quoted replies, and common English words, words occurring in
# only one document or in at least 95% of the documents are removed.

print("Loading dataset...")
t0 = time()
# data, _ = fetch_20newsgroups(shuffle=True, random_state=1,
#                              remove=('headers', 'footers', 'quotes'),
#                              return_X_y=True)
data_samples = data[:n_samples]
print("done in %0.3fs." % (time() - t0))

# Use tf-idf features for NMF.
print("Extracting tf-idf features for NMF...")
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2,
                                   max_features=n_features,
                                   stop_words=stop_list)
t0 = time()
tfidf = tfidf_vectorizer.fit_transform(data_samples)
print("done in %0.3fs." % (time() - t0))

# Use tf (raw term count) features for LDA.
print("Extracting tf features for LDA...")
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2,
                                max_features=n_features,
                                stop_words=stop_list)
t0 = time()
tf = tf_vectorizer.fit_transform(data_samples)
print("done in %0.3fs." % (time() - t0))
print()

# Fit the NMF model
print("Fitting the NMF model (Frobenius norm) with tf-idf features, "
      "n_samples=%d and n_features=%d..."
      % (n_samples, n_features))
t0 = time()
nmf = NMF(n_components=n_components, random_state=1,
          alpha=.1, l1_ratio=.5).fit(tfidf)
print("done in %0.3fs." % (time() - t0))

print("\nTopics in NMF model (Frobenius norm):")
tfidf_feature_names = tfidf_vectorizer.get_feature_names()
print_top_words(nmf, tfidf_feature_names, n_top_words)

# Fit the NMF model
print("Fitting the NMF model (generalized Kullback-Leibler divergence) with "
      "tf-idf features, n_samples=%d and n_features=%d..."
      % (n_samples, n_features))
t0 = time()
nmf = NMF(n_components=n_components, random_state=1,
          beta_loss='kullback-leibler', solver='mu', max_iter=1000, alpha=.1,
          l1_ratio=.5).fit(tfidf)
print("done in %0.3fs." % (time() - t0))

print("\nTopics in NMF model (generalized Kullback-Leibler divergence):")
tfidf_feature_names = tfidf_vectorizer.get_feature_names()
print_top_words(nmf, tfidf_feature_names, n_top_words)

print("Fitting LDA models with tf features, "
      "n_samples=%d and n_features=%d..."
      % (n_samples, n_features))
lda = LatentDirichletAllocation(n_components=n_components, max_iter=5,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=0)
t0 = time()
lda.fit(tf)
print("done in %0.3fs." % (time() - t0))

print("\nTopics in LDA model:")
tf_feature_names = tf_vectorizer.get_feature_names()
print_top_words(lda, tf_feature_names, n_top_words)
# Out:
# Loading dataset...
# done in 0.001s.
# Extracting tf-idf features for NMF...
# done in 0.139s.
# Extracting tf features for LDA...
# done in 0.151s.
#
# Fitting the NMF model (Frobenius norm) with tf-idf features, n_samples=2000 and n_features=1000...
# done in 0.360s.
#
# Topics in NMF model (Frobenius norm):
# Topic #0: one little time much use bag tried eat try well
# Topic #1: chips kettle potato bag chip bags salty brand regular crunchy
# Topic #2: tea teas drink black drinking green loose iced years morning
# Topic #3: food cat cats old eat baby problems dogs dry foods
# Topic #4: like really better others even kind spicy nothing lot though
# Topic #5: salt vinegar sea pepper favorite sour bbq onion original chips
# Topic #6: coffee cup bitter drink instant blend pods cups tastes use
# Topic #7: price amazon find local store stores grocery cereal shipping found
# Topic #8: love delicious stuff way also husband get sweet pasta flavored
# Topic #9: great snack tastes size loves make healthy without deal looking
# Topic #10: sugar raw use white stevia brown regular agave much sweet
# Topic #11: good really pretty tastes healthy tasty tasting stuff try quality
# Topic #12: product www http href gp com use using amazon ounce
# Topic #13: best ever tried tasted tasting market eaten earth stevia real
# Topic #14: flavor favorite bbq sauce hot strong probably far better really
# Topic #15: mix waffle pancake easy make pancakes add milk waffles cup
# Topic #16: taste energy healthy also feel amazing get salty bad ok
# Topic #17: dog treats loves dogs food harmony farms liver small natural
# Topic #18: flavors popchips pack variety calories 100 snack bags single 24
# Topic #19: buy would recommend never thought highly loved okay definitely way
# Topic #20: chocolate dark pocky mint version cups cookies caramel wonderful stick
#
# Fitting the NMF model (generalized Kullback-Leibler divergence) with tf-idf features, n_samples=2000 and n_features=1000...
# done in 3.304s.
#
# Topics in NMF model (generalized Kullback-Leibler divergence):
# Topic #0: time first one two good actually much long well even
# Topic #1: chips potato chip kettle salt flavor bags bag crunchy vinegar
# Topic #2: tea drink black flavor drinking like green teas bitter cup
# Topic #3: food dog old eat loves dogs year one dry also
# Topic #4: like flavor taste even bit one really bad different better
# Topic #5: great flavors love favorite salt popchips variety pepper snack pack
# Topic #6: coffee one order box get great ordered flavors day could
# Topic #7: amazon product price store order shipping disappointed bought get local
# Topic #8: best ever favorite time one love first tried many every
# Topic #9: great product better use taste used made purchase using natural
# Topic #10: love much also sugar use delicious absolutely little sweet go
# Topic #11: good really price try tasty makes always quality pretty delivery
# Topic #12: product flavor pack like bags com really ordered 24 gp
# Topic #13: one good excellent free use need could calories regular best
# Topic #14: amazon find great flavor price stores found local better hard
# Topic #15: make little easy add mix like perfect cook price open
# Topic #16: taste like get tried family know loves feel make also
# Topic #17: fresh arrived came box chocolate size perfect small ordered tasted
# Topic #18: bag calories eat buy anything like fat high low healthy
# Topic #19: buy would recommend bought highly anyone could never loved everything
# Topic #20: eat find free chocolate hard wonderful almost many able gluten
#
# Fitting LDA models with tf features, n_samples=2000 and n_features=1000...
# done in 3.501s.
#
# Topics in LDA model:
# Topic #0: sauce hot egg soy bottle allergy fish calcium noodles eggs
# Topic #1: dirty meat trip turkey style milk canned processed breakfast apples
# Topic #2: ordered pod gift chocolate christmas well got store pack received
# Topic #3: cereal nuts gold brands filled money half price little keep
# Topic #4: cacao aware alive oats shipped herbal pounds cocoa 50 ok
# Topic #5: coffee cake cup frosting powder pineapple cakes family milk made
# Topic #6: wonderful food cannot try almost live experience fish world red
# Topic #7: chips salt potato flavors kettle vinegar flavor bag chip popchips
# Topic #8: roasted farms harmony beans sure smooth smell plenty home combination
# Topic #9: com amazon mix waffle http www gp href product pack
# Topic #10: dry cats food omaha frozen steaks cat meat oven canned
# Topic #11: low carb diet stevia 00 nustevia agave blood substitute products
# Topic #12: also good dog expensive feeding amount food healthy gave buying
# Topic #13: believe pick immediately american ever cakes gourmet drink results plain
# Topic #14: licorice candy hard caramels chewy candies yum strawberry original world
# Topic #15: food dog one good like dogs try treats old also
# Topic #16: like great good taste flavor product love one tea would
# Topic #17: best like great flavor ever tasted taste fruit good fresh
# Topic #18: juice olive donut sampler cups shop decaf dirty peanuts smooth
# Topic #19: someone version recommend around highly issues wrapped yummy balance candy
# Topic #20: intake excellent expecting delivery home products company needs guilt watch

# %%
# Try 2 topics but 300k samples

# Author: Olivier Grisel <olivier.grisel@ensta.org>
#         Lars Buitinck
#         Chyi-Kwei Yau <chyikwei.yau@gmail.com>
# License: BSD 3 clause

from time import time

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
from sklearn.datasets import fetch_20newsgroups

n_samples = 300000
n_features = 1000
n_components = 2
n_top_words = 30


def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        message = "Topic #%d: " % topic_idx
        message += " ".join([feature_names[i]
                             for i in topic.argsort()[:-n_top_words - 1:-1]])
        print(message)
    print()


# Load the 20 newsgroups dataset and vectorize it. We use a few heuristics
# to filter out useless terms early on: the posts are stripped of headers,
# footers and quoted replies, and common English words, words occurring in
# only one document or in at least 95% of the documents are removed.

print("Loading dataset...")
t0 = time()
# data, _ = fetch_20newsgroups(shuffle=True, random_state=1,
#                              remove=('headers', 'footers', 'quotes'),
#                              return_X_y=True)
data_samples = data[:n_samples]
print("done in %0.3fs." % (time() - t0))

# Use tf-idf features for NMF.
print("Extracting tf-idf features for NMF...")
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2,
                                   max_features=n_features,
                                   stop_words=stop_list)
t0 = time()
tfidf = tfidf_vectorizer.fit_transform(data_samples)
print("done in %0.3fs." % (time() - t0))

# Use tf (raw term count) features for LDA.
print("Extracting tf features for LDA...")
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2,
                                max_features=n_features,
                                stop_words=stop_list)
t0 = time()
tf = tf_vectorizer.fit_transform(data_samples)
print("done in %0.3fs." % (time() - t0))
print()

# Fit the NMF model
print("Fitting the NMF model (Frobenius norm) with tf-idf features, "
      "n_samples=%d and n_features=%d..."
      % (n_samples, n_features))
t0 = time()
nmf = NMF(n_components=n_components, random_state=1,
          alpha=.1, l1_ratio=.5).fit(tfidf)
print("done in %0.3fs." % (time() - t0))

print("\nTopics in NMF model (Frobenius norm):")
tfidf_feature_names = tfidf_vectorizer.get_feature_names()
print_top_words(nmf, tfidf_feature_names, n_top_words)

# Fit the NMF model
print("Fitting the NMF model (generalized Kullback-Leibler divergence) with "
      "tf-idf features, n_samples=%d and n_features=%d..."
      % (n_samples, n_features))
t0 = time()
nmf = NMF(n_components=n_components, random_state=1,
          beta_loss='kullback-leibler', solver='mu', max_iter=1000, alpha=.1,
          l1_ratio=.5).fit(tfidf)
print("done in %0.3fs." % (time() - t0))

print("\nTopics in NMF model (generalized Kullback-Leibler divergence):")
tfidf_feature_names = tfidf_vectorizer.get_feature_names()
print_top_words(nmf, tfidf_feature_names, n_top_words)

print("Fitting LDA models with tf features, "
      "n_samples=%d and n_features=%d..."
      % (n_samples, n_features))
lda = LatentDirichletAllocation(n_components=n_components, max_iter=5,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=0)
t0 = time()
lda.fit(tf)
print("done in %0.3fs." % (time() - t0))

print("\nTopics in LDA model:")
tf_feature_names = tf_vectorizer.get_feature_names()
print_top_words(lda, tf_feature_names, n_top_words)
# Out:
# Loading dataset...
# done in 0.004s.
# Extracting tf-idf features for NMF...
# done in 20.169s.
# Extracting tf features for LDA...
# done in 19.501s.
#
# Fitting the NMF model (Frobenius norm) with tf-idf features, n_samples=300000 and n_features=1000...
# done in 17.964s.
#
# Topics in NMF model (Frobenius norm):
# Topic #0: coffee like good great product taste one flavor love would food amazon really get price much use buy time little chocolate best find also better tried make well even eat
# Topic #1: tea green teas drink flavor cup bags black iced taste like love good drinking strong hot great chai water one loose bag favorite leaves best caffeine day tastes brew leaf
#
# Fitting the NMF model (generalized Kullback-Leibler divergence) with tf-idf features, n_samples=300000 and n_features=1000...
# done in 47.144s.
#
# Topics in NMF model (generalized Kullback-Leibler divergence):
# Topic #0: good like great product one love amazon taste buy get flavor also best would better much find really even price little time bought make use eat food well delicious found
# Topic #1: coffee tea flavor cup drink taste cups strong green best bitter favorite blend drinking brew morning black bold teas smooth hot nice enjoy flavored keurig tried coffees aroma decaf dark
#
# Fitting LDA models with tf features, n_samples=300000 and n_features=1000...
# done in 493.625s.
#
# Topics in LDA model:
# Topic #0: like taste flavor coffee tea good great one chocolate sugar love water really sweet product drink use make cup tastes also would tried best much little better milk hot try
# Topic #1: product one food amazon great good like would get time price love buy find much store eat well order box dog use bought even really also little bag first two

# %%
data_brief = df.sample(2000)

# %%
cmap = plt.cm.get_cmap('viridis', 21)

# %%
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer

from yellowbrick.text import TSNEVisualizer
from yellowbrick.datasets import load_hobbies

# Load the data and create document vectors
tfidf = TfidfVectorizer()

X = tfidf.fit_transform(data_brief.Text)
clusters = KMeans(n_clusters=21)
clusters.fit(X)

tsne = TSNEVisualizer(colormap=cmap)
tsne.fit(X, ["c{}".format(c) for c in clusters.labels_])
tsne.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
cmap = plt.cm.get_cmap('RdBu')

# %%
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer

from yellowbrick.text import TSNEVisualizer
from yellowbrick.datasets import load_hobbies

# Load the data and create document vectors
tfidf = TfidfVectorizer()

X = tfidf.fit_transform(data_brief.Text)
clusters = KMeans(n_clusters=2)
clusters.fit(X)

tsne = TSNEVisualizer(colormap=cmap)
tsne.fit(X, ["c{}".format(c) for c in clusters.labels_])
tsne.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
